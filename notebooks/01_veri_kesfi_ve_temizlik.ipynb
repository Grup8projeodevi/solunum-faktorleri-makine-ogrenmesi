# %% [markdown]
# # Adım 1: Veri Yükleme ve Temizleme
# Bu aşamada ham veri seti yüklenecek, analiz için hedef değişkenler seçilecek ve geçersiz (bilmiyorum/reddedildi) yanıtlar temizlenecektir.

# %%
import pandas as pd
import numpy as np

print("1/5: Veri yükleniyor ve temizleniyor...")

# Doğru klasör yolundan ham veriyi okuyoruz
df = pd.read_csv('../data/brfss_survey_data_2024.csv')
df_grup8 = df[['_STATE', 'ASTHMA3', 'CHCCOPD3', 'EXERANY2']].copy()

# Geçersiz kodları boş değer (NaN) yapıyoruz
for kolon in ['ASTHMA3', 'CHCCOPD3', 'EXERANY2']:
    df_grup8[kolon] = df_grup8[kolon].replace([7, 9, 77, 99], np.nan)

print("Temizlik sonrası eksik veri durumları:")
print(df_grup8.isnull().sum())

# 2. adıma aktarmak için ara veriyi kaydediyoruz
df_grup8.to_csv('../data/adimbasi_temiz_veri.csv', index=False)
print("\nAra veri 'adimbasi_temiz_veri.csv' olarak kaydedildi.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3
#       4 print("1/5: Veri yükleniyor ve temizleniyor...")
#
# File c:\Users\eyupk\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\__init__.py:58
#      55 # let init-time option registration happen
#      56 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 58 from pandas.core.api import (
#      59     # dtype
#      60     ArrowDtype,
#      61     Int8Dtype,
#      62     Int16Dtype,
#      63     Int32Dtype,
#      64     Int64Dtype,
#      65     UInt8Dtype,
#      66     UInt16Dtype,
#      67     UInt32Dtype,
#      68     UInt64Dtype,
#      69     Float32Dtype,
#      70     Float64Dtype,
#      71     CategoricalDtype,
#      72     PeriodDtype,
#      73     IntervalDtype,
#      74     DatetimeTZDtype,
#      75     StringDtype,
#      76     BooleanDtype,
#      77     # missing
#      78     NA,
#      79     isna,
#      80     isnull,
#      81     notna,
#      82     notnull,
#      83     # indexes
#      84     Index,
#      85     CategoricalIndex,
#      86     RangeIndex,
#      87     MultiIndex,
#      88     IntervalIndex,
#      89     TimedeltaIndex,
#      90     DatetimeIndex,
#      91     PeriodIndex,
#      92     IndexSlice,
#      93     # tseries
#      94     NaT,
#      95     Period,
#      96     period_range,
#      97     Timedelta,
#      98     timedelta_range,
#      99     Timestamp,
#     100     date_range,
#     101     bdate_range,
#     102     Interval,
#     103     interval_range,
#     104     DateOffset,
#     105     # conversion
#     106     to_numeric,
#     107     to_datetime,
#     108     to_timedelta,
#     109     # misc
#     110     Flags,
#     111     Grouper,
#     112     factorize,
#     113     unique,
#     114     NamedAgg,
#     115     array,
#     116     Categorical,
#     117     set_eng_float_format,
#     118     Series,
#     119     DataFrame,
#     120 )
#     121 from pandas.core.col import col
#     123 from pandas.core.dtypes.dtypes import SparseDtype
#
# File c:\Users\eyupk\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\api.py:27
#      16 from pandas.core.dtypes.missing import (
#      17     isna,
#      18     isnull,
#      19     notna,
#      20     notnull,
#      21 )
#      23 from pandas.core.algorithms import (
#      24     factorize,
#      25     unique,
#      26 )
# ---> 27 from pandas.core.arrays import Categorical
#      28 from pandas.core.arrays.boolean import BooleanDtype
#      29 from pandas.core.arrays.floating import (
#      30     Float32Dtype,
#      31     Float64Dtype,
#      32 )
#
# File c:\Users\eyupk\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\arrays\__init__.py:12
#      10 from pandas.core.arrays.floating import FloatingArray
#      11 from pandas.core.arrays.integer import IntegerArray
# ---> 12 from pandas.core.arrays.interval import IntervalArray
#      13 from pandas.core.arrays.masked import BaseMaskedArray
#      14 from pandas.core.arrays.numpy_ import NumpyExtensionArray
#
# File <frozen importlib._bootstrap>:1371, in _find_and_load(name, import_)
#    1367         getattr(getattr(module, "__spec__", None), "_initializing", False)):
#    1368         with _ModuleLockManager(name):
#    1369             module = sys.modules.get(name, _NEEDS_LOADING)
#    1370             if module is _NEEDS_LOADING:
# -> 1371                 return _find_and_load_unlocked(name, import_)
#    1372
#    1373         # Optimization: only call _bootstrap._lock_unlock_module() if
#    1374         # module.__spec__._initializing is True.
#
# File <frozen importlib._bootstrap>:1345, in _find_and_load_unlocked(name, import_)
#    1341         try:
#    1342             module = _load_unlocked(spec)
#    1343         finally:
#    1344             if parent_spec:
# -> 1345                 parent_spec._uninitialized_submodules.pop()
#    1346     if parent:
#    1347         # Set the module as an attribute on its parent.
#    1348         parent_module = sys.modules[parent]
#
# File <frozen importlib._bootstrap>:953, in _load_unlocked(spec)
#     949         module = sys.modules.pop(spec.name)
#     950         sys.modules[spec.name] = module
#     951         _verbose_message('import {!r} # {!r}', spec.name, spec.loader)
#     952     finally:
# --> 953         spec._initializing = False
#     954
#     955     return module
#
# File <frozen importlib._bootstrap_external>:758, in _LoaderBasics.exec_module(self, module)
#     756     def exec_module(self, module):
#     757         """Execute the module."""
# --> 758         code = self.get_code(module.__name__)
#     759         if code is None:
#     760             raise ImportError(f'cannot load module {module.__name__!r} when '
#     761                               'get_code() returns None')
#
# File <frozen importlib._bootstrap_external>:855, in SourceLoader.get_code(self, fullname)
#     851             else:
#     852                 source_mtime = int(st['mtime'])
#     853                 try:
#     854                     data = self.get_data(bytecode_path)
# --> 855                 except OSError:
#     856                     pass
#     857                 else:
#     858                     exc_details = {
#
# File <frozen importlib._bootstrap_external>:953, in FileLoader.get_data(self, path)
#     950     def get_data(self, path):
#     951         """Return the data from path as raw bytes."""
#     952         if isinstance(self, (SourceLoader, ExtensionFileLoader)):
# --> 953             with _io.open_code(str(path)) as file:
#     954                 return file.read()
#     955         else:
#     956             with _io.FileIO(path, 'r') as file:
#
# KeyboardInterrupt:
